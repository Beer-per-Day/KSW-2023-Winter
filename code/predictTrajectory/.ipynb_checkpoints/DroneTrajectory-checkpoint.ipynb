# %% [markdown]
# | Usage list | version |
# |---|:---:|
# | `python` | 3.9.12 |
# | `numpy` | 1.21.5 |  |
# | `pandas` | 1.4.2 |
# | `verstack` | 3.6.5 |
# | `sklearn` | 1.0.2 |
# | `matplotlib` | 3.5.1 |

# %% [markdown]
# ## Dataset : Drone trajectory Dataset based on DJI simulator

# %%
! pip install verstack
# Out:
# Requirement already satisfied: verstack in c:\conda1\lib\site-packages (3.6.5)
# Requirement already satisfied: xgboost in c:\conda1\lib\site-packages (from verstack) (1.7.1)
# Requirement already satisfied: optuna<=3.0.4,>=2.10.0 in c:\conda1\lib\site-packages (from verstack) (3.0.4)
# Requirement already satisfied: plotly<=5.11.0,>=5.3.1 in c:\conda1\lib\site-packages (from verstack) (5.6.0)
# Requirement already satisfied: holidays==0.11.3.1 in c:\conda1\lib\site-packages (from verstack) (0.11.3.1)
# Requirement already satisfied: tensorflow<=2.11.0,>=2.6.0 in c:\conda1\lib\site-packages (from verstack) (2.11.0)
# Requirement already satisfied: pandas in c:\conda1\lib\site-packages (from verstack) (1.4.2)
# Requirement already satisfied: mlxtend in c:\conda1\lib\site-packages (from verstack) (0.21.0)
# Requirement already satisfied: category-encoders<=2.5.1,>=2.4.0 in c:\conda1\lib\site-packages (from verstack) (2.5.1)
# Requirement already satisfied: python-dateutil<=2.8.2,>=2.8.1 in c:\conda1\lib\site-packages (from verstack) (2.8.2)
# Requirement already satisfied: keras<=2.11.0,>=2.6.0 in c:\conda1\lib\site-packages (from verstack) (2.11.0)
# Requirement already satisfied: numpy in c:\conda1\lib\site-packages (from verstack) (1.21.5)
# Requirement already satisfied: matplotlib in c:\conda1\lib\site-packages (from verstack) (3.5.1)
# Requirement already satisfied: lightgbm<=3.3.2,>=3.3.0 in c:\conda1\lib\site-packages (from verstack) (3.3.2)
# Requirement already satisfied: scikit-learn<=1.1.3,>=0.23.2 in c:\conda1\lib\site-packages (from verstack) (1.0.2)
# Requirement already satisfied: korean-lunar-calendar in c:\conda1\lib\site-packages (from holidays==0.11.3.1->verstack) (0.3.1)
# Requirement already satisfied: convertdate>=2.3.0 in c:\conda1\lib\site-packages (from holidays==0.11.3.1->verstack) (2.4.0)
# Requirement already satisfied: hijri-converter in c:\conda1\lib\site-packages (from holidays==0.11.3.1->verstack) (2.2.4)
# Requirement already satisfied: patsy>=0.5.1 in c:\conda1\lib\site-packages (from category-encoders<=2.5.1,>=2.4.0->verstack) (0.5.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\conda1\lib\site-packages (from category-encoders<=2.5.1,>=2.4.0->verstack) (1.7.3)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\conda1\lib\site-packages (from category-encoders<=2.5.1,>=2.4.0->verstack) (0.13.2)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in c:\conda1\lib\site-packages (from convertdate>=2.3.0->holidays==0.11.3.1->verstack) (0.5.12)
# Requirement already satisfied: wheel in c:\conda1\lib\site-packages (from lightgbm<=3.3.2,>=3.3.0->verstack) (0.37.1)
# Requirement already satisfied: colorlog in c:\conda1\lib\site-packages (from optuna<=3.0.4,>=2.10.0->verstack) (6.7.0)
# Requirement already satisfied: PyYAML in c:\conda1\lib\site-packages (from optuna<=3.0.4,>=2.10.0->verstack) (6.0)
# Requirement already satisfied: cliff in c:\conda1\lib\site-packages (from optuna<=3.0.4,>=2.10.0->verstack) (4.1.0)
# Requirement already satisfied: cmaes>=0.8.2 in c:\conda1\lib\site-packages (from optuna<=3.0.4,>=2.10.0->verstack) (0.9.1)
# Requirement already satisfied: tqdm in c:\conda1\lib\site-packages (from optuna<=3.0.4,>=2.10.0->verstack) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in c:\conda1\lib\site-packages (from optuna<=3.0.4,>=2.10.0->verstack) (21.3)
# Requirement already satisfied: alembic>=1.5.0 in c:\conda1\lib\site-packages (from optuna<=3.0.4,>=2.10.0->verstack) (1.9.2)
# Requirement already satisfied: importlib-metadata<5.0.0 in c:\conda1\lib\site-packages (from optuna<=3.0.4,>=2.10.0->verstack) (4.11.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\conda1\lib\site-packages (from optuna<=3.0.4,>=2.10.0->verstack) (1.4.32)
# Requirement already satisfied: Mako in c:\conda1\lib\site-packages (from alembic>=1.5.0->optuna<=3.0.4,>=2.10.0->verstack) (1.2.4)
# Requirement already satisfied: zipp>=0.5 in c:\conda1\lib\site-packages (from importlib-metadata<5.0.0->optuna<=3.0.4,>=2.10.0->verstack) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\conda1\lib\site-packages (from packaging>=20.0->optuna<=3.0.4,>=2.10.0->verstack) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\conda1\lib\site-packages (from pandas->verstack) (2021.3)
# Requirement already satisfied: six in c:\conda1\lib\site-packages (from patsy>=0.5.1->category-encoders<=2.5.1,>=2.4.0->verstack) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\conda1\lib\site-packages (from plotly<=5.11.0,>=5.3.1->verstack) (8.0.1)
# Requirement already satisfied: joblib>=0.11 in c:\conda1\lib\site-packages (from scikit-learn<=1.1.3,>=0.23.2->verstack) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\conda1\lib\site-packages (from scikit-learn<=1.1.3,>=0.23.2->verstack) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\conda1\lib\site-packages (from sqlalchemy>=1.3.0->optuna<=3.0.4,>=2.10.0->verstack) (1.1.1)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\conda1\lib\site-packages (from tensorflow<=2.11.0,>=2.6.0->verstack) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (1.12.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (1.42.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (2.1.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (3.6.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (4.1.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (3.19.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (1.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (23.1.21)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (0.30.0)
# Requirement already satisfied: setuptools in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (61.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\conda1\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (15.0.6.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\conda1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\conda1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\conda1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (1.33.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\conda1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (2.0.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\conda1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\conda1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\conda1\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\conda1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\conda1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\conda1\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\conda1\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\conda1\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\conda1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\conda1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\conda1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\conda1\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\conda1\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow<=2.11.0,>=2.6.0->verstack) (3.2.2)
# Requirement already satisfied: PrettyTable>=0.7.2 in c:\conda1\lib\site-packages (from cliff->optuna<=3.0.4,>=2.10.0->verstack) (3.6.0)
# Requirement already satisfied: cmd2>=1.0.0 in c:\conda1\lib\site-packages (from cliff->optuna<=3.0.4,>=2.10.0->verstack) (2.4.3)
# Requirement already satisfied: stevedore>=2.0.1 in c:\conda1\lib\site-packages (from cliff->optuna<=3.0.4,>=2.10.0->verstack) (4.1.1)
# Requirement already satisfied: autopage>=0.4.0 in c:\conda1\lib\site-packages (from cliff->optuna<=3.0.4,>=2.10.0->verstack) (0.5.1)
# Requirement already satisfied: wcwidth>=0.1.7 in c:\users\정주헌\appdata\roaming\python\python39\site-packages (from cmd2>=1.0.0->cliff->optuna<=3.0.4,>=2.10.0->verstack) (0.2.5)
# Requirement already satisfied: pyreadline3 in c:\conda1\lib\site-packages (from cmd2>=1.0.0->cliff->optuna<=3.0.4,>=2.10.0->verstack) (3.4.1)
# Requirement already satisfied: attrs>=16.3.0 in c:\conda1\lib\site-packages (from cmd2>=1.0.0->cliff->optuna<=3.0.4,>=2.10.0->verstack) (21.4.0)
# Requirement already satisfied: pyperclip>=1.6 in c:\conda1\lib\site-packages (from cmd2>=1.0.0->cliff->optuna<=3.0.4,>=2.10.0->verstack) (1.8.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\conda1\lib\site-packages (from stevedore>=2.0.1->cliff->optuna<=3.0.4,>=2.10.0->verstack) (5.11.1)
# Requirement already satisfied: colorama in c:\users\정주헌\appdata\roaming\python\python39\site-packages (from colorlog->optuna<=3.0.4,>=2.10.0->verstack) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\conda1\lib\site-packages (from Mako->alembic>=1.5.0->optuna<=3.0.4,>=2.10.0->verstack) (2.0.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\conda1\lib\site-packages (from matplotlib->verstack) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\conda1\lib\site-packages (from matplotlib->verstack) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\conda1\lib\site-packages (from matplotlib->verstack) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\conda1\lib\site-packages (from matplotlib->verstack) (0.11.0)

# %%
# import & call data
import numpy as np
import pandas as pds
import os
from numpy import array


# for second in range(1, 6):     # create dataset per unit second.
#     for i in range(10, 16):
#         df = pds.read_csv(f'./UAVDataset/uavTrajectoryData{i}.csv', header=0, index_col=0)
#         df = df.iloc[[j*2*second  for j in range(df.shape[0] // (second * 2))], :]

#         df.to_csv(f"./UAVDataset/second{second}/uavTrajectoryData{i}.csv", mode='w')

data = pds.read_csv(
    os.path.join('UAVDataset/second3/uavTrajectoryData15.csv'),
)
data_1 = pds.read_csv(
    os.path.join('UAVDataset/second3/uavTrajectoryData11.csv'),
)
data_2 = pds.read_csv(
    os.path.join('UAVDataset/second3/uavTrajectoryData12.csv'),
)
data_3 = pds.read_csv(
    os.path.join('UAVDataset/second3/uavTrajectoryData13.csv'),
)
data_4 = pds.read_csv(
    os.path.join('UAVDataset/second3/uavTrajectoryData14.csv'),
)

# upload the data files
data_test = pds.read_csv(
    os.path.join('UAVDataset/second3/uavTrajectoryData10.csv'),
)

# %% [markdown]
# # Pre-Processing

# %%
def sep_train2target(datas):             # separate the dataset as train, target
    datas = datas.dropna()
    dataset = datas[['time', 'lat', 'lon', 'alt']]
    lat_frame = dataset['lat']
    lon_frame = dataset['lon']
    alt_frame = dataset['alt']
    
    data_train = []
    data_target = []
    for i in range(len(dataset) - 10):   # set the 30 features and target data
        temp_train = []
        temp_target = []
        for j in range(i,i+10):
            temp_train.append(lat_frame[j])
            temp_train.append(lon_frame[j])
            temp_train.append(alt_frame[j])
        temp_target.append(lat_frame[i+10])
        temp_target.append(lon_frame[i+10])
        temp_target.append(alt_frame[i+10])
        np.array(temp_train)
        np.array(temp_target)
        data_train.append(temp_train)
        data_target.append(temp_target)

    data_train = np.asarray(data_train)
    data_target = np.asarray(data_target)
    
    return data_train, data_target

# %%
data_train, data_target = sep_train2target(data)
data_train_1, data_target_1 = sep_train2target(data_1)
data_train_2, data_target_2 = sep_train2target(data_2)
data_train_3, data_target_3 = sep_train2target(data_3)
data_train_4, data_target_4 = sep_train2target(data_4)
# data_train_5, data_target_5 = sep_train2target(data_5)
# data_train_6, data_target_6 = sep_train2target(data_6)
# data_train_7, data_target_7 = sep_train2target(data_7)

test_train, test_target = sep_train2target(data_test)
# data_train_4, data_target_4 = sep_train2target(data_4)
# data_train_5, data_target_5 = sep_train2target(data_5)
# data_train_6, data_target_6 = sep_train2target(data_6)
# data_train_7, data_target_7 = sep_train2target(data_7)
# data_train_8, data_target_8 = sep_train2target(data_8)

# %%
def merge_data(main, sub):
    return np.concatenate((main, sub), axis = 0)

def array2series(target):
    result_lat = target[: ,0]
    result_lat = pds.DataFrame(result_lat)
    result_lat = result_lat.squeeze()
    
    result_log = target[: ,1]
    result_log = pds.DataFrame(result_log)
    result_log = result_log.squeeze()
    
    result_alt = target[: ,2]
    result_alt = pds.DataFrame(result_alt)
    result_alt = result_alt.squeeze()
    
    return result_lat, result_log, result_alt

# %%
data_train_list = [data_train_1, data_train_2, data_train_3, data_train_4]
data_target_list = [data_target_1, data_target_2, data_target_3, data_target_4]
train_final = data_train
target_final = data_target
data_train_list
for i in range(len(data_train_list)):
    train_final = merge_data(train_final, data_train_list[i])
    target_final = merge_data(target_final, data_target_list[i])

target_lat, target_lon, target_alt = array2series(target_final)
test_target_lat, test_target_lon, test_target_alt = array2series(test_target)

# %%
len(target_final), len(test_target)
# Out:
# (3577, 403)

# %% [markdown]
# # Set the target data:

# %%
import verstack
from verstack.stratified_continuous_split import scsplit    # KFold is not available. 
train_final = pds.DataFrame(train_final)      # KFold supports classification data. But our data type is continuous
target_data = target_lat                      # set the target data : [target_lat, target_lon, target_alt]
X_train, X_val, y_train, y_val = scsplit(train_final, target_data, stratify = target_data)
# X_train, y_train type => pds.DataFrame  X_val, y_val type => pds.Series
X_lon_train, X_lon_val, y_lon_train, y_lon_val = scsplit(train_final, target_lon, stratify = target_lon)
X_alt_train, X_alt_val, y_alt_train, y_alt_val = scsplit(train_final, target_alt, stratify = target_alt)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
def make_MAPE(y_test, y_pred):
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

def eval_model(true_list, pre_list):
    MAE = mean_absolute_error(true_list, pre_list)
    MSE = mean_squared_error(true_list, pre_list)
    RMSE = np.sqrt(MSE)
    pre_list = pds.DataFrame(pre_list)
    pre_list = pre_list.squeeze()
    MAPE = make_MAPE(true_list, pds.Series(pre_list))
    return MAE, RMSE, MAPE

def make_error_list(total_list):
    MAE_list = [total_list[0][0], total_list[1][0], total_list[2][0]]
    RMSE_list = [total_list[0][1], total_list[1][1], total_list[2][1]]
    MAPE_list = [total_list[0][2], total_list[1][2], total_list[2][2]]
    return MAE_list, RMSE_list, MAPE_list

# %% [markdown]
# # Linear Regression

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor    # check the Multicollinearity
vif = pds.DataFrame()
vif['VIF_Factor'] = [variance_inflation_factor(train_final.values, i)
                        for i in range(train_final.shape[1])]
vif['Feature'] = train_final.columns
vif
# Out:
#       VIF_Factor  Feature
# 0   5.880141e+11        0
# 1   2.169887e+12        1
# 2   2.836650e+04        2
# 3   3.931558e+12        3
# 4   1.544974e+13        4
# 5   1.656128e+05        5
# 6   6.320842e+12        6
# 7   2.580859e+13        7
# 8   2.335085e+05        8
# 9   6.912663e+12        9
# 10  2.841388e+13       10
# 11  2.393352e+05       11
# 12  7.086703e+12       12
# 13  2.914951e+13       13
# 14  2.402832e+05       14
# 15  7.075569e+12       15
# 16  2.924415e+13       16
# 17  2.403967e+05       17
# 18  6.854794e+12       18
# 19  2.886923e+13       19
# 20  2.401915e+05       20
# 21  6.263699e+12       21
# 22  2.656991e+13       22
# 23  2.354412e+05       23
# 24  3.921288e+12       24
# 25  1.585775e+13       25
# 26  1.677131e+05       26
# 27  5.906747e+11       27
# 28  2.206025e+12       28
# 29  2.895123e+04       29

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
# latitude
model_error_list = []    # error per model
scx_list = []
scy_list = []
trainx_list = [X_train, X_lon_train, X_alt_train]
trainy_list = [y_train, y_lon_train, y_alt_train]
validX_list = [X_val, X_lon_val, X_alt_val]
validy_list = [y_val, y_lon_val, y_alt_val]
test_list = [test_target_lat, test_target_lon, test_target_alt]

stdX_list = []
stdy_list = []
stdX_val_list = []
stdX_test_list = []

LR_predict_list = []
LR_error_list = []
LR_test_result_list = []    # test result data list
LR_test_error_list = []     # test error list


stdX_list = []
stdy_list = []
stdX_val_list = []

for i in range(3):        # Standard normalization
    sc_x = StandardScaler()
    sc_y = StandardScaler()
    
    stdX_list.append(sc_x.fit_transform(trainx_list[i]))
    stdy_list.append(sc_y.fit_transform(trainy_list[i].values.reshape((-1, 1))))
    
    stdX_val_list.append(sc_x.transform(validX_list[i]))
    stdX_test_list.append(sc_x.transform(test_train))
    scx_list.append(sc_x)
    scy_list.append(sc_y)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

Ridge_alpha_list = []
Ridge_predict_list = []
Ridge_error_list = []
for i in range(3):
    parameters = {'alpha':[1, 2, 3, 4, 5, 6]}
    Ridge_reg= GridSearchCV(Ridge(), parameters, scoring='neg_mean_squared_error',cv=5)
    Ridge_reg.fit(stdX_list[i], stdy_list[i])
    
    Ridge_alpha_list.append(Ridge_reg.best_params_["alpha"])
    reg = Ridge(alpha=Ridge_reg.best_params_["alpha"]).fit(stdX_list[i], stdy_list[i])
       
    predict_test = reg.predict(stdX_test_list[i])
    predict_test = scy_list[i].inverse_transform(predict_test.reshape((-1, 1)))
    
    TMAE, TRMSE, TMAPE = eval_model(test_list[i], predict_test)
    Ridge_predict_list.append(predict_test)
    Ridge_error_list.append([TMAE, TRMSE, TMAPE])

# %%
from matplotlib import pyplot as plt
x = np.arange(len(test_target))              # Linear Regression Visualization

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.show()
# X_val, y_val, y_predict
ax[0].title.set_text("Ridge Regression Test (lat)")
ax[0].plot(x, test_target_lat, color = 'tab:blue', label='real')
ax[0].plot(x, Ridge_predict_list[0], color = 'tab:red', label='predict')
ax[0].legend()


ax[1].title.set_text("Ridge Regression Test (lon)")
ax[1].plot(x, test_target_lon, color = 'tab:blue', label='real')
ax[1].plot(x, Ridge_predict_list[1], color = 'tab:red', label='predict')
ax[1].legend()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.show()
ax[0].title.set_text("Ridge Regression Test (alt)")
ax[0].plot(x, test_target_alt, color = 'tab:blue', label='real')
ax[0].plot(x, Ridge_predict_list[2], color = 'tab:red', label='predict')
ax[0].legend()

TMAE_list, TRMSE_list, TMAPE_list = make_error_list(Ridge_error_list)
model_error_list.append(('TRidge_MAE', np.mean(TMAE_list)))
model_error_list.append(('TRidge_RMSE', np.mean(TRMSE_list)))
model_error_list.append(('TRidge_MAPE', np.mean(TMAPE_list)))
errors = np.arange(3)
err_values = [np.mean(TMAE_list), np.mean(TRMSE_list), np.mean(TMAPE_list)]
err_names = ['MAE', 'RMSE', 'MAPE']
plt.title("Ridge Regression")
plt.bar(errors, err_values)
plt.xticks(errors, err_names)
model_error_list
# Out:
# [('TRidge_MAE', 0.24218548607968093),
#  ('TRidge_RMSE', 0.3665060159650302),
#  ('TRidge_MAPE', 0.24968873614178722)]

# %%
for i in range(3):
    reg = LinearRegression().fit(stdX_list[i], stdy_list[i])
    
    
    predict_linear = reg.predict(stdX_val_list[i])
    predict_linear = scy_list[i].inverse_transform(predict_linear.reshape((-1, 1)))
    
    predict_test = reg.predict(stdX_test_list[i])
    predict_test = scy_list[i].inverse_transform(predict_test.reshape((-1, 1)))
    
    MAE, RMSE, MAPE = eval_model(validy_list[i], predict_linear)
    LR_predict_list.append(predict_linear)
    LR_error_list.append([MAE, RMSE, MAPE])
    TMAE, TRMSE, TMAPE = eval_model(test_list[i], predict_test)
    LR_test_result_list.append(predict_test)
    LR_test_error_list.append([TMAE, TRMSE, TMAPE])

# %%
from matplotlib import pyplot as plt
x = np.arange(len(test_target))              # Linear Regression Visualization

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.show()
# X_val, y_val, y_predict
ax[0].title.set_text("Linear Regression Test (lat)")
ax[0].plot(x, test_target_lat, color = 'tab:blue', label='real')
ax[0].plot(x, LR_test_result_list[0], color = 'tab:red', label='predict')
ax[0].legend()


ax[1].title.set_text("Linear Regression Test (lon)")
ax[1].plot(x, test_target_lon, color = 'tab:blue', label='real')
ax[1].plot(x, LR_test_result_list[1], color = 'tab:red', label='predict')
ax[1].legend()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.show()
ax[0].title.set_text("Linear Regression Test (alt)")
ax[0].plot(x, test_target_alt, color = 'tab:blue', label='real')
ax[0].plot(x, LR_test_result_list[2], color = 'tab:red', label='predict')
ax[0].legend()

TMAE_list, TRMSE_list, TMAPE_list = make_error_list(LR_test_error_list)
model_error_list.append(('TLR_MAE', np.mean(TMAE_list)))
model_error_list.append(('TLR_RMSE', np.mean(TRMSE_list)))
model_error_list.append(('TLR_MAPE', np.mean(TMAPE_list)))
errors = np.arange(3)
err_values = [np.mean(TMAE_list), np.mean(TRMSE_list), np.mean(TMAPE_list)]
err_names = ['MAE', 'RMSE', 'MAPE']
plt.title("Linear Regression")
plt.bar(errors, err_values)
plt.xticks(errors, err_names)
model_error_list
# Out:
# [('TRidge_MAE', 0.24218548607968093),
#  ('TRidge_RMSE', 0.3665060159650302),
#  ('TRidge_MAPE', 0.24968873614178722),
#  ('TLR_MAE', 0.15930538558155785),
#  ('TLR_RMSE', 0.2815838131439531),
#  ('TLR_MAPE', 0.1402917435654001)]

# %% [markdown]
# # Ensemble: model  type = LinearRegression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingRegressor

BR_best_predict_list = []
BR_best_error_list = []

BR_best_test_predict_list = []
BR_best_test_error_list = []

BR_best_params = []

for i in range(3):
    parameters = {
    "n_estimators": [5, 10, 30]
    }

    grid = GridSearchCV(BaggingRegressor(), parameters, cv=5, verbose=1)
    grid.fit(stdX_list[i], stdy_list[i])
    BR_best_params.append(grid.best_params_["n_estimators"])
    
    regr_best = BaggingRegressor(LinearRegression(), n_estimators= grid.best_params_["n_estimators"], random_state=0).fit(stdX_list[i], stdy_list[i])
    ensemble_predict_best = regr_best.predict(stdX_val_list[i])
    ensemble_predict_best = sc_y.inverse_transform(ensemble_predict_best.reshape((-1, 1)))
    
    predict_test = regr_best.predict(stdX_test_list[i])
    predict_test = scy_list[i].inverse_transform(predict_test.reshape((-1, 1)))
    
    
    MAE, RMSE, MAPE = eval_model(validy_list[i], ensemble_predict_best)
    BR_best_predict_list.append(ensemble_predict_best)
    BR_best_error_list.append([MAE, RMSE, MAPE])
    
    TMAE, MRMSE,TMAPE = eval_model(test_list[i], predict_test)
    BR_best_test_predict_list.append(predict_test)
    BR_best_test_error_list.append([TMAE, TRMSE, TMAPE])
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Fitting 5 folds for each of 3 candidates, totalling 15 fits

# %%
model_error_list
# Out:
# [('TRidge_MAE', 0.24218548607968093),
#  ('TRidge_RMSE', 0.3665060159650302),
#  ('TRidge_MAPE', 0.24968873614178722),
#  ('TLR_MAE', 0.15930538558155785),
#  ('TLR_RMSE', 0.2815838131439531),
#  ('TLR_MAPE', 0.1402917435654001)]

# %%
from matplotlib import pyplot as plt
x = np.arange(len(test_target))              # Linear Regression Visualization
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.show()
# X_val, y_val, y_predict
ax[0].title.set_text("Bagging Regression Test (lat)")
ax[0].plot(x, test_target_lat, color = 'tab:blue', label='real')
ax[0].plot(x, BR_best_test_predict_list[0], color = 'tab:red', label='predict')
ax[0].legend()


ax[1].title.set_text("Bagging Regression Test (lon)")
ax[1].plot(x, test_target_lon, color = 'tab:blue', label='real')
ax[1].plot(x, BR_best_test_predict_list[1], color = 'tab:red', label='predict')
ax[1].legend()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.show()
ax[0].title.set_text("Bagging Regression Test (alt)")
ax[0].plot(x, test_target_alt, color = 'tab:blue', label='real')
ax[0].plot(x, BR_best_test_predict_list[2], color = 'tab:red', label='predict')
ax[0].legend()

TMAE_list, TRMSE_list, TMAPE_list = make_error_list(BR_best_test_error_list)
model_error_list.append(('TBR_MAE', np.mean(TMAE_list)))
model_error_list.append(('TBR_RMSE', np.mean(TRMSE_list)))
model_error_list.append(('TBR_MAPE', np.mean(TMAPE_list)))
errors = np.arange(3)
err_values = [np.mean(TMAE_list), np.mean(TRMSE_list), np.mean(TMAPE_list)]
err_names = ['MAE', 'RMSE', 'MAPE']
plt.title("Bagging Regression")
plt.bar(errors, err_values)
plt.xticks(errors, err_names)
model_error_list
# Out:
# [('TRidge_MAE', 0.24218548607968093),
#  ('TRidge_RMSE', 0.3665060159650302),
#  ('TRidge_MAPE', 0.24968873614178722),
#  ('TLR_MAE', 0.15930538558155785),
#  ('TLR_RMSE', 0.2815838131439531),
#  ('TLR_MAPE', 0.1402917435654001),
#  ('TBR_MAE', 0.1617620706954624),
#  ('TBR_RMSE', 0.8445882188286623),
#  ('TBR_MAPE', 0.1442634936919013)]

# %% [markdown]
# # Support Vector Machine (SVM) :

# %% [markdown]
# # apply SVM
# from sklearn.svm import LinearSVR, SVR
# from sklearn.pipeline import make_pipeline
#
# regr_svm = make_pipeline(StandardScaler(), LinearSVR(random_state=0, tol=1e-5))
# regr_svm.fit(X_train, y_train)
# predict_svm = regr_svm.predict(X_val)
#
# svm_MAE = mean_absolute_error(y_val,predict_svm)
# svm_MSE = mean_squared_error(y_val, predict_svm)
# svm_RMSE = np.sqrt(svm_MSE)
# svm_MAPE = make_MAPE(y_val, predict_svm)
#
# predict_svm

# %%
# apply SVM 
from sklearn.svm import LinearSVR, SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

rbf_predict_list = []
rbf_error_list = []
rbf_test_predict_list = []
rbf_test_error_list = []
rbf_best_params = []
for i in range(3):
    parameters = {
    "kernel": ['rbf'],
    "C": [1, 10, 100, 1000, 10000],
    "gamma": [1e-9, 1e-8, 1e-7, 1e-6, 1e-5, 1e-4]
    }
     
    grid = GridSearchCV(SVR(), parameters,cv=5, verbose=1)
    grid.fit(stdX_list[i], stdy_list[i])
    
    print("running now")
    
    rbf_best_params.append([grid.best_params_["gamma"], grid.best_params_["C"]])
    svr = SVR(kernel="rbf", gamma=grid.best_params_["gamma"], C=grid.best_params_["C"])
    svr.fit(stdX_list[i], stdy_list[i])
    
    predict_svr = svr.predict(stdX_val_list[i])
    predict_svr = scy_list[i].inverse_transform(predict_svr.reshape((-1, 1)))
    
    predict_test = svr.predict(stdX_test_list[i])
    predict_test = scy_list[i].inverse_transform(predict_test.reshape((-1, 1)))
    
#     MAE, RMSE, MAPE = eval_model(validy_list[i], predict_svr)
#     rbf_predict_list.append(predict_svr)
#     rbf_error_list.append([MAE, RMSE, MAPE])
    TMAE, TRMSE, TMAPE = eval_model(test_list[i], predict_test)
    rbf_test_predict_list.append(predict_test)
    rbf_test_error_list.append([TMAE, TRMSE, TMAPE])
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# running now
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# running now
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# running now

# %%
x = np.arange(len(test_target))
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.show()
# X_val, y_val, y_predict
ax[0].title.set_text("SVM with rbf Test (lat)")
ax[0].plot(x, test_target_lat, color = 'tab:blue', label='real')
ax[0].plot(x, rbf_test_predict_list[0], color = 'tab:red', label='predict')
ax[0].legend()

ax[1].title.set_text("SVM with rbf Test (lon)")
ax[1].plot(x, test_target_lon, color = 'tab:blue', label='real')
ax[1].plot(x, rbf_test_predict_list[1], color = 'tab:red', label='predict')
ax[1].legend()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.show()
# X_val, y_val, y_predict
ax[0].title.set_text("SVM with rbf Test (alt)")
ax[0].plot(x, test_target_alt, color = 'tab:blue', label='real')
ax[0].plot(x, rbf_test_predict_list[2], color = 'tab:red', label='predict')
ax[0].legend()

MAE_list, RMSE_list, MAPE_list = make_error_list(rbf_test_error_list)
model_error_list.append(('rbf_MAE', np.mean(MAE_list)))
model_error_list.append(('rbf_RMSE', np.mean(RMSE_list)))
model_error_list.append(('rbf_MAPE', np.mean(MAPE_list)))
errors = np.arange(3)
err_values = [np.mean(MAE_list), np.mean(RMSE_list), np.mean(MAPE_list)]
plt.title("SVM with rbf")
err_names = ['MAE', 'RMSE', 'MAPE']
plt.bar(errors, err_values)
plt.xticks(errors, err_names)
model_error_list
# Out:
# [('TRidge_MAE', 0.24218548607968093),
#  ('TRidge_RMSE', 0.3665060159650302),
#  ('TRidge_MAPE', 0.24968873614178722),
#  ('TLR_MAE', 0.15930538558155785),
#  ('TLR_RMSE', 0.2815838131439531),
#  ('TLR_MAPE', 0.1402917435654001),
#  ('TBR_MAE', 0.1617620706954624),
#  ('TBR_RMSE', 0.8445882188286623),
#  ('TBR_MAPE', 0.1442634936919013),
#  ('rbf_MAE', 0.5006506639482952),
#  ('rbf_RMSE', 0.6257936476771262),
#  ('rbf_MAPE', 0.34625903088673643)]

# %%
model_error_list = dict(model_error_list)
model_error_list
# Out:
# {'TRidge_MAE': 0.24218548607968093,
#  'TRidge_RMSE': 0.3665060159650302,
#  'TRidge_MAPE': 0.24968873614178722,
#  'TLR_MAE': 0.15930538558155785,
#  'TLR_RMSE': 0.2815838131439531,
#  'TLR_MAPE': 0.1402917435654001,
#  'TBR_MAE': 0.1617620706954624,
#  'TBR_RMSE': 0.8445882188286623,
#  'TBR_MAPE': 0.1442634936919013,
#  'rbf_MAE': 0.5006506639482952,
#  'rbf_RMSE': 0.6257936476771262,
#  'rbf_MAPE': 0.34625903088673643}

# %%
model_error_list = dict(model_error_list)
model_error_list
cols = ['MAE', "RMSE", "MAPE"]
idx = ['Linear Regression','SVM with rbf','Bagging Regressor']
temp =[[model_error_list['TRidge_MAE'], model_error_list['TRidge_RMSE'], model_error_list['TRidge_MAPE']],
       [model_error_list['rbf_MAE'],model_error_list['rbf_RMSE'],model_error_list['rbf_MAPE']],
       [model_error_list['TBR_MAE'],model_error_list['TBR_RMSE'],model_error_list['TBR_MAPE']]]
compare_ensemble = pds.DataFrame(temp, columns=cols, index =idx)
compare_ensemble
# Out:
#                         MAE      RMSE      MAPE
# Linear Regression  0.242185  0.366506  0.249689
# SVM with rbf       0.500651  0.625794  0.346259
# Bagging Regressor  0.161762  0.844588  0.144263

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def show_3D_trajectory(result_list, title):
    fig = plt.figure(figsize=(9, 6))
    
    ax = fig.add_subplot(111, projection='3d')
    ax.set_title(title)
   
    x = result_list[0].transpose().squeeze()
    y = result_list[1].transpose().squeeze()
    z = result_list[2].transpose().squeeze()
    
    true_x = test_target_lat
    true_y = test_target_lon
    true_z = test_target_alt
    
    ax.plot(true_x, true_y, true_z, color = 'b', label = 'True Trajectory')
    ax.plot(x, y, z, color = 'r', label = title +' Trajectory')

    ax.legend()
    # ax.scatter(x, y, z, color = 'r', alpha = 0.5)
    # ax.scatter(true_x, true_y, true_z, color = 'b', alpha = 0.5)

# %%
show_3D_trajectory(LR_test_result_list, 'Linear Regression')

# %%
show_3D_trajectory(Ridge_predict_list, 'Ridge Regression')

# %%
show_3D_trajectory(BR_best_test_predict_list, 'Bagging Regressor')

# %%
show_3D_trajectory(rbf_test_predict_list, 'Soft Vector Machine')

# %%
plt.title('Result MAPE')
models = ['Ridge', 'Ensemble', 'SVM']
ranges = np.arange(3)
values = [model_error_list['TRidge_MAPE'], model_error_list['TBR_MAPE'], model_error_list['rbf_MAPE']]
plt.bar(ranges, values)
plt.xticks(ranges, models)
# Out:
# ([<matplotlib.axis.XTick at 0x1efb53c7d90>,
#   <matplotlib.axis.XTick at 0x1efb53c74f0>,
#   <matplotlib.axis.XTick at 0x1efb4e51e50>],
#  [Text(0, 0, 'Ridge'), Text(1, 0, 'Ensemble'), Text(2, 0, 'SVM')])

# %%
print('Ridge_alpha')
Ridge_alpha_list
# Out:
# Ridge_alpha
# [1, 1, 1]

# %%
print('Bagging Regression')
BR_best_params
# Out:
# Bagging Regression
# [30, 30, 30]

# %%
print('rbf SVM')
rbf_best_params
# Out:
# rbf SVM
# [[0.0001, 10000], [0.0001, 10000], [1e-05, 10000]]
